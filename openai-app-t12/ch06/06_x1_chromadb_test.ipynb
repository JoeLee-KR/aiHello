# %%
import sys
print(sys.executable)
print(sys.path)
# Out:
# /Users/doogie/opt/anaconda3/envs/py09/bin/python
# ['/Users/doogie/DevOps/aiappHello', '/Applications/PyCharm.app/Contents/plugins/python-ce/helpers/pydev', '/Applications/PyCharm.app/Contents/plugins/python-ce/helpers/jupyter_debug', '/Users/doogie/opt/anaconda3/envs/py09/lib/python39.zip', '/Users/doogie/opt/anaconda3/envs/py09/lib/python3.9', '/Users/doogie/opt/anaconda3/envs/py09/lib/python3.9/lib-dynload', '', '/Users/doogie/opt/anaconda3/envs/py09/lib/python3.9/site-packages', '/Users/doogie/opt/anaconda3/envs/py09/lib/python3.9/site-packages/setuptools/_vendor']

# %%
try:
    import chromadb
except Exception as e:
    print("CHROMADB LOAD ERROR:", repr(e))

# %%
try:
    import chromadb
except Exception as e:
    import traceback
    traceback.print_exc()

# %%
def split_list(lst, n):
    """
    리스트 lst를 n개의 거의 균등한 부분으로 분할
    """
    k, m = divmod(len(lst), n)
    return [lst[i*k + min(i, m):(i+1)*k + min(i+1, m)] for i in range(n)]

def split_list2( lst, n):
    k, m = divmod(len(lst), n)
    print( k,m)
    for i in range(n):
        print( i, i*k + min(i, m), (i+1)*k + min(i+1, m) )
        tmplist[i]=lst[i*k + min(i, m): (i+1)*k + min(i+1, m)]
    return tmplist

data = list(range(14))
print(f"data: {data[:5]} ... {data[-5:]}")

# 3개로 분할
parts = split_list2(data, 3)

for i, p in enumerate(parts):
    print(f"part {i+1}: len = {len(p)}")
#print( len(parts) )

for i in range(len(parts)):
    print(f"parts: {parts[i][:5]} ... {parts[i][-5:]}")
# Out:
# data: [0, 1, 2, 3, 4] ... [9, 10, 11, 12, 13]
# 4 2
# 0 0 5
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 20
#      17 print(f"data: {data[:5]} ... {data[-5:]}")
#      19 # 3개로 분할
# ---> 20 parts = split_list2(data, 3)
#      22 for i, p in enumerate(parts):
#      23     print(f"part {i+1}: len = {len(p)}")
#
# Cell In[30], line 13, in split_list2(lst, n)
#      11 for i in range(n):
#      12     print( i, i*k + min(i, m), (i+1)*k + min(i+1, m) )
# ---> 13     tmplist[i]=lst[i*k + min(i, m): (i+1)*k + min(i+1, m)]
#      14 return tmplist
#
# NameError: name 'tmplist' is not defined

# %% [markdown]
# #### chromadb test code
# - import, from features od chromadb
# - real storaging for chromadb

# %%
import chromadb

# chromadb client 생성
chroma_client = chromadb.Client()

# collection 생성
collection = chroma_client.create_collection(name="my_collection")

# collection 에 텍스트 추가
collection.add(
    documents=[
        "This is a document about pineapple",
        "This is a document about oranges"
    ],
    ids=["id1", "id2"]
)

# collection에 쿼리 날리기
results = collection.query(
    query_texts=["This is a query document about hawaii"], # Chroma will embed this for you
    n_results=2 # how many results to return
)
print(results)

# 또다른 쿼리 날려보기
results = collection.query(
    query_texts=["This is a query document about florida"], # Chroma will embed this for you
    n_results=2 # how many results to return
)
print(results)
# Out:
# /Users/doogie/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz: 100%|██████████| 79.3M/79.3M [00:20<00:00, 4.13MiB/s]
# {'ids': [['id1', 'id2']], 'embeddings': None, 'documents': [['This is a document about pineapple', 'This is a document about oranges']], 'uris': None, 'included': ['metadatas', 'documents', 'distances'], 'data': None, 'metadatas': [[None, None]], 'distances': [[1.0404009819030762, 1.2430801391601562]]}
# {'ids': [['id2', 'id1']], 'embeddings': None, 'documents': [['This is a document about oranges', 'This is a document about pineapple']], 'uris': None, 'included': ['metadatas', 'documents', 'distances'], 'data': None, 'metadatas': [[None, None]], 'distances': [[1.1462137699127197, 1.3015384674072266]]}

# %%
import chromadb

# chromadb client 생성
chroma_client = chromadb.Client()
