# %%
from dotenv import load_dotenv
import os
from openai import OpenAI

load_dotenv("../../_apikeys.env")
api_key = os.getenv("Doogie.2ndKey")
openAIClient = OpenAI(api_key=api_key)

response = openAIClient.chat.completions.create(
  model="gpt-4-turbo",
  messages=[
    {
      "role": "user",
      "content": [
        {"type": "text", "text": "이 이미지에 대해서 알려줘"},
        {
          "type": "image_url",
          "image_url": {
            "url": "https://upload.wikimedia.org/wikipedia/commons/thumb/d/dd/Gfp-wisconsin-madison-the-nature-boardwalk.jpg/2560px-Gfp-wisconsin-madison-the-nature-boardwalk.jpg",
          },
        },
      ],
    }
  ],
  max_tokens=300,
)
print(response.choices[0])
# Out:
# Completion tokens: 247
# Prompt tokens: 1124
# Total tokens: 1371
# Total bill:0.018650 USD
# Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='이 사진은 넓은 초록색 초원과 그 사이를 가로지르는 나무 데크가 있는 평화로운 자연 풍경을 보여줍니다. 하늘은 맑고 푸른색이며 구름이 부드럽게 펼쳐져 있습니다. 나무 데크는 방문객들이 젖지 않고 푸른 잔디와 습지를 거닐 수 있게 해줍니다. 이 경치는 자연의 아름다움을 즐기러 오는 이들에게 탁월한 산책로를 제공할 것입니다. 이미지가 촬영된 시간은 아마도 늦은 오후 또는 이른 저녁으로 추정됩니다. 자연 관찰, 산책, 사진 촬영 등의 활동에 적합한 장소로 보입니다.', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))

# %%
print("Completion tokens:", response.usage.completion_tokens)
print("Prompt tokens:", response.usage.prompt_tokens)
print("Total tokens:", response.usage.total_tokens)
total_bill = (response.usage.completion_tokens * 30 +
              response.usage.prompt_tokens * 10 ) / 1000000
print(f"Total bill:{total_bill:.6f}", "USD")
# Out:
# Completion tokens: 247
# Prompt tokens: 1124
# Total tokens: 1371
# Total bill:0.018650 USD

# %%
print("response.choices[0].message.content=", response.choices[0].message.content)
print("length=", len(response.choices[0].message.content) )
# Out:
# response.choices[0].message.content= 이 사진은 넓은 초록색 초원과 그 사이를 가로지르는 나무 데크가 있는 평화로운 자연 풍경을 보여줍니다. 하늘은 맑고 푸른색이며 구름이 부드럽게 펼쳐져 있습니다. 나무 데크는 방문객들이 젖지 않고 푸른 잔디와 습지를 거닐 수 있게 해줍니다. 이 경치는 자연의 아름다움을 즐기러 오는 이들에게 탁월한 산책로를 제공할 것입니다. 이미지가 촬영된 시간은 아마도 늦은 오후 또는 이른 저녁으로 추정됩니다. 자연 관찰, 산책, 사진 촬영 등의 활동에 적합한 장소로 보입니다.
# length= 259
