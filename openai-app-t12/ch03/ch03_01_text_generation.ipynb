# %%
print("Hello. notebook...")
print("5bae767342b64d00b080c31d92f212f6")
# Out:
# Hello. notebook...
# 5bae767342b64d00b080c31d92f212f6

# %%
import openai
from dotenv import load_dotenv
import os

load_dotenv("../../_apikeys.env")
OPENAI_API_KEY = os.getenv("Doogie.2ndKey")

client = openai.OpenAI( api_key = OPENAI_API_KEY )

response = client.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[{"role": "user", "content": "Tell me how to make a pizza"}]
)

print(response)
# Out:
# ChatCompletion(id='chatcmpl-BlUFBkfoP69xzVnWKCmKRNZ4V2aT3', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='To make a pizza, you will need the following ingredients:\n\n- Pizza dough (you can make your own or buy pre-made dough)\n- Pizza sauce\n- Cheese (mozzarella is the most commonly used)\n- Toppings of your choice (such as pepperoni, vegetables, or meats)\n- Olive oil\n\nHere are the basic steps to make a pizza:\n\n1. Preheat your oven to the temperature specified on your pizza dough package or recipe.\n2. Roll out the pizza dough on a floured surface to your desired thickness.\n3. Place the rolled out dough on a pizza stone or baking sheet.\n4. Spread a layer of pizza sauce on the dough, leaving a small border around the edges.\n5. Sprinkle a generous amount of cheese on top of the sauce.\n6. Add your desired toppings on top of the cheese.\n7. Drizzle some olive oil over the top of the pizza.\n8. Place the pizza in the preheated oven and bake for about 10-15 minutes, or until the crust is golden and the cheese is melted and bubbly.\n9. Remove the pizza from the oven and let it cool for a few minutes before slicing and serving.\n\nEnjoy your homemade pizza! Feel free to customize the toppings and seasonings to suit your preferences.', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1750657373, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=261, prompt_tokens=14, total_tokens=275, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))

# %%
print(response.choices[0].message.content)
# Out:
# Here is a basic recipe for making a pizza from scratch:
#
# Ingredients:
# - 1 ½ cups warm water
# - 2 ¼ tsp active dry yeast
# - 4 cups all-purpose flour
# - 1 tsp salt
# - 1 tsp sugar
# - 2 tbsp olive oil
#
# Instructions:
# 1. In a small bowl, dissolve the yeast in warm water and let it sit for about 5 minutes until it becomes frothy.
# 2. In a large mixing bowl, combine the flour, salt, and sugar. Make a well in the center and pour in the yeast mixture and olive oil.
# 3. Using a wooden spoon or your hands, mix the dough until it comes together. Knead the dough on a lightly floured surface for about 5-7 minutes until it becomes smooth and elastic.
# 4. Place the dough in a lightly greased bowl, cover with a clean towel, and let it rise in a warm place for about 1-2 hours or until it doubles in size.
# 5. Preheat your oven to 475°F (245°C) and place a baking stone or pizza pan in the oven to heat up.
# 6. Once the dough has risen, punch it down and divide it into desired portions. Roll out each portion into a circle or rectangular shape on a lightly floured surface.
# 7. Place the rolled-out dough on a piece of parchment paper and add your desired toppings (sauce, cheese, vegetables, meats, etc.).
# 8. Carefully transfer the pizza with the parchment paper onto the preheated baking stone or pan in the oven.
# 9. Bake the pizza for about 10-15 minutes or until the crust is golden brown and the cheese is melted and bubbly.
# 10. Remove the pizza from the oven, let it cool for a few minutes, slice, and enjoy!
#
# Feel free to get creative with your toppings and experiment with different flavors to make your perfect pizza. Enjoy!

# %%
print(response.usage.completion_tokens)
print(response.usage.prompt_tokens)
print(response.usage.total_tokens)
total_bill = (response.usage.completion_tokens * 1.5 +
              response.usage.prompt_tokens * 0.5 ) / 1000000
print(f"Total bill:{total_bill:.6f}", "USD")
print(response.usage)
# Out:
# 396
# 14
# 410
# Total bill:0.000601 USD
# CompletionUsage(completion_tokens=396, prompt_tokens=14, total_tokens=410, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))

# %%
import openai
from dotenv import load_dotenv
import os

load_dotenv("../../_apikeys.env")
OPENAI_API_KEY = os.getenv("Doogie.2ndKey")

client = openai.OpenAI( api_key = OPENAI_API_KEY )

response = client.chat.completions.create(
  model="gpt-4o-mini",
  messages=[{"role": "user", "content": "Tell me how to make a pizza"}]
)

print(response)
# Out:
# ChatCompletion(id='chatcmpl-BYmxW5gsyAHQpN6REpD4J2Tl9gIfo', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='Making a pizza at home can be a fun and rewarding experience! Here’s a simple recipe to make a classic homemade pizza from scratch.\n\n### Ingredients\n\n#### For the Dough:\n- 2 1/4 teaspoons (1 packet) active dry yeast\n- 1 teaspoon sugar\n- 3/4 cup warm water (110°F / 45°C)\n- 2 cups all-purpose flour (plus extra for dusting)\n- 1 teaspoon salt\n- 1 tablespoon olive oil\n\n#### For the Toppings:\n- 1/2 cup pizza sauce (store-bought or homemade)\n- 1 to 2 cups shredded mozzarella cheese\n- Toppings of your choice (pepperoni, bell peppers, onions, mushrooms, olives, etc.)\n- Olive oil (for brushing)\n- Dried oregano or Italian seasoning (optional)\n\n### Instructions\n\n#### Step 1: Prepare the Dough\n1. **Activate the Yeast**: In a small bowl, mix the warm water, sugar, and yeast. Let it sit for about 5-10 minutes until it becomes frothy.\n  \n2. **Make the Dough**: In a large mixing bowl, combine the flour and salt. Create a well in the center and pour in the yeast mixture and olive oil. Mix until a dough begins to form.\n\n3. **Knead the Dough**: Turn the dough out onto a floured surface and knead for about 5-7 minutes until it’s smooth and elastic. You may need to add a little more flour if the dough is sticky.\n\n4. **Let it Rise**: Place the dough in a lightly greased bowl, cover with a kitchen towel or plastic wrap, and let it rise in a warm place for about 1 hour or until it doubles in size.\n\n#### Step 2: Preheat the Oven\n- Preheat your oven to 475°F (245°C) and if you have a pizza stone, place it in the oven to heat up as well.\n\n#### Step 3: Shape the Pizza\n1. **Punch Down**: Once the dough has risen, punch it down to release the air. \n\n2. **Roll Out the Dough**: On a floured surface, roll out the dough to your desired thickness for the pizza. A 10-12 inch diameter is ideal for a standard pizza. \n\n3. **Transfer to a Baking Sheet or Pizza Stone**: If you’re using a baking sheet, lightly grease it or sprinkle with cornmeal. If using a pizza stone, you can transfer the dough onto a pizza peel covered with flour before transferring to the stone.\n\n#### Step 4: Add Toppings\n1. **Spread the Sauce**: Evenly spread the pizza sauce over the surface of the dough, leaving a small border for the crust.\n\n2. **Add Cheese**: Sprinkle the shredded mozzarella cheese on top of the sauce.\n\n3. **Add Other Toppings**: Add your favorite toppings evenly over the cheese. \n\n4. **Finish with Olive Oil**: Lightly brush the edges of the crust with olive oil for a golden color and sprinkle with dried oregano or Italian seasoning if desired.\n\n#### Step 5: Bake the Pizza\n- Bake in the preheated oven for about 12-15 minutes, or until the crust is golden brown and the cheese is bubbly and slightly browned.\n\n#### Step 6: Slice and Serve\n- Remove the pizza from the oven and let it cool for a few minutes. Slice it into wedges and serve hot!\n\n### Enjoy!\nFeel free to experiment with different sauces, cheeses, and toppings to create your perfect pizza. Enjoy your homemade pizza!', refusal=None, role='assistant', audio=None, function_call=None, tool_calls=None, annotations=[]))], created=1747631050, model='gpt-4o-mini-2024-07-18', object='chat.completion', service_tier='default', system_fingerprint='fp_54eb4bd693', usage=CompletionUsage(completion_tokens=744, prompt_tokens=14, total_tokens=758, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))

# %%
print(response.choices[0].message.content)
# Out:
# Here is a basic recipe for making a pizza from scratch:
#
# Ingredients:
# - 1 ½ cups warm water
# - 2 ¼ tsp active dry yeast
# - 4 cups all-purpose flour
# - 1 tsp salt
# - 1 tsp sugar
# - 2 tbsp olive oil
#
# Instructions:
# 1. In a small bowl, dissolve the yeast in warm water and let it sit for about 5 minutes until it becomes frothy.
# 2. In a large mixing bowl, combine the flour, salt, and sugar. Make a well in the center and pour in the yeast mixture and olive oil.
# 3. Using a wooden spoon or your hands, mix the dough until it comes together. Knead the dough on a lightly floured surface for about 5-7 minutes until it becomes smooth and elastic.
# 4. Place the dough in a lightly greased bowl, cover with a clean towel, and let it rise in a warm place for about 1-2 hours or until it doubles in size.
# 5. Preheat your oven to 475°F (245°C) and place a baking stone or pizza pan in the oven to heat up.
# 6. Once the dough has risen, punch it down and divide it into desired portions. Roll out each portion into a circle or rectangular shape on a lightly floured surface.
# 7. Place the rolled-out dough on a piece of parchment paper and add your desired toppings (sauce, cheese, vegetables, meats, etc.).
# 8. Carefully transfer the pizza with the parchment paper onto the preheated baking stone or pan in the oven.
# 9. Bake the pizza for about 10-15 minutes or until the crust is golden brown and the cheese is melted and bubbly.
# 10. Remove the pizza from the oven, let it cool for a few minutes, slice, and enjoy!
#
# Feel free to get creative with your toppings and experiment with different flavors to make your perfect pizza. Enjoy!

# %%
print(response.usage.completion_tokens)
print(response.usage.prompt_tokens)
print(response.usage.total_tokens)
total_bill = (response.usage.completion_tokens * 0.6 +
              response.usage.prompt_tokens * 0.15 ) / 1000000
print(total_bill, "USD")
print(response.usage)
# Out:
# 396
# 14
# 410
# 0.0002397 USD
# CompletionUsage(completion_tokens=396, prompt_tokens=14, total_tokens=410, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))

# %%
import openai
from dotenv import load_dotenv
import os

load_dotenv("../../_apikeys.env")
OPENAI_API_KEY = os.getenv("Doogie.2ndKey")

client = openai.OpenAI( api_key = OPENAI_API_KEY )

response = client.chat.completions.create(
  model="gpt-4o-mini",
  messages=[
      {"role": "system", "content": "You are a translator that translates users' inputs. If the input is in Korean, it must be translated into English. This must be strictly adhered to."},
      {"role": "user", "content": "2020년 월드시리즈는 누가 우승했어?"}
    ]
  )

print(response.choices[0].message.content)
# Out:
# Who won the 2020 World Series?

# %%
import openai
from dotenv import load_dotenv
import os

load_dotenv("../../_apikeys.env")
OPENAI_API_KEY = os.getenv("Doogie.2ndKey")

client = openai.OpenAI( api_key = OPENAI_API_KEY )

response = client.chat.completions.create(
  model="gpt-4o-mini",
  messages=[
      {"role": "user", "content": "2002년 월드컵에서 가장 화제가 되었던 나라는 어디야?"}
    ]
  )

print(response.choices[0].message.content)
# Out:
# 2002년 월드컵에서 가장 화제가 되었던 나라는 한국과 일본이었습니다. 이 대회는 한국과 일본이 공동으로 개최한 첫 번째 월드컵으로, 한국은 4강에 진출하며 큰 화제를 모았습니다. 한국은 이 대회에서 이탈리아와 스페인을 각각 꺾고 4강에 진출하는 이른바 "드라마틱"한 경기를 펼쳤습니다. 이로 인해 한국 축구의 위상이 크게 상승하게 되었고, 많은 사람들에게 깊은 인상을 남겼습니다.

# %%
response = client.chat.completions.create(
  model="gpt-4o-mini",
  messages=[
      {"role": "user", "content": "2002년 월드컵에서 가장 화제가 되었던 나라는 어디야?"},
      {"role": "assistant", "content": "예상을 뚫고 4강 신화를 일으킨 한국입니다."},
      {"role": "user", "content": "그 나라가 화제가 되었던 이유를 자세하게 설명해줘."}
    ]
  )

print(response.choices[0].message.content)
# Out:
# 2002년 월드컵에서 한국이 화제가 된 이유는 여러 가지가 있습니다:
#
# 1. **4강 진출**: 한국은 2002년 한일 월드컵에서 최초로 아시아 국가로서 4강에 진출했습니다. 이는 월드컵 역사상 큰 이정표로, 많은 사람들에게 큰 감동을 주었습니다.
#
# 2. **특유의 조직력과 투지**: 한국 팀은 뛰어난 체력과 조직력을 바탕으로 강팀들을 상대로 놀라운 경기력을 보여주었습니다. 조별 리그에서는 폴란드와 미국을 이기고, 포르투갈과의 16강전에서는 극적인 역전승을 거두었습니다.
#
# 3. **심판 논란**: 한국의 8강전에서 이탈리아를 상대로 한 경기는 여러 논란을 야기했습니다. 한국이 VAR과 같은 현대적 심판 시스템이 없던 시절에 두 개의 논란 많은 판정을 얻어 승리한 것이었고, 이로 인해 경기 후 이탈리아와 많은 축구 팬들 사이에서 논란이 일었습니다.
#
# 4. **국민적 열광**: 한국에서 열린 월드컵이라는 특수한 상황으로 인해, 모든 국민이 월드컵에 열광하며, 거리 응원을 했다. 이는 한국 사회 전체의 단결과 공동체 의식을 강화하는 계기가 되었습니다.
#
# 5. **축구의 대중화**: 한국의 월드컵 성과는 국내 축구의 인기를 끌어올리는 데 크게 기여했습니다. 이후 많은 젊은이들이 축구에 관심을 가지게 되었고, 프로리그와 청소년 축구의 발전에도 도움을 주었습니다.
#
# 이러한 요소들이 결합하여 2002년 월드컵에서 한국은 역사적인 순간을 만들어냈고, 이는 지금까지도 많은 사람들에게 기억되고 있습니다.

# %%
import openai
from dotenv import load_dotenv
import os

load_dotenv("../../_apikeys.env")
OPENAI_API_KEY = os.getenv("Doogie.2ndKey")

client = openai.OpenAI( api_key = OPENAI_API_KEY )

response = client.chat.completions.create(
  model="gpt-4o-mini",
  response_format={"type": "json_object"},
  messages=[
      {"role": "system", "content": "You are helpful assistant designed to output JSON."},
      {"role": "user", "content": "Who won the world series in 2002?"}
    ]
  )

print(response.choices[0].message.content)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import openai
# ----> 2 from dotenv import load_dotenv
#       3 import os
#       5 load_dotenv("../../_apikeys.env")
#
# ModuleNotFoundError: No module named 'dotenv'
